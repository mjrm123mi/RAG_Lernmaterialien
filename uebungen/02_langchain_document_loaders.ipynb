# %%
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader('../Data/text_files/text1.txt')
doc = loader.load()
print(len(doc))
# Out:
# 1

# %%
# Requirements:
# LangChain Unstructured + libmagic
# https://docs.langchain.com/oss/python/integrations/providers/unstructured

# %%
from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader("../Data/text_files", glob="*.txt")
docs = loader.load()
print(len(docs))

# ... to be continued (chunking -> embedding -> indexing)
# Out:
# 3

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(
    "../Data/pdf_files/pdf1.pdf",
    mode='page')
docs = loader.load()
print(len(docs))

docs
# Out:
# 33
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader([
    "https://www.htw-berlin.de/",
     "https://www.female-techtalk.com"
     ])

docs = loader.load()

print(len(docs))

docs
# Out:
# 2
# ...
